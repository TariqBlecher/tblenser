# %%
# %pylab inline
import pyfits as pf
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
lensed.sum()/twod.sum(),sampled.sum()/twod.sum()
# Out:
# (3.3301085494398244, 1.1647871171960575)

# %%
lensed = pf.getdata('single_image.fits')
imshow(lensed)

# %%
sampled=pf.getdata('single_source.fits')
imshow(sampled)

# %%
threed = load('rolled_disk.npy')

# %%
twod = sum(threed,axis=2)
imshow(twod)

# %%
imshow((twod-sampled)/twod)
colorbar()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in divide
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in divide
#   """Entry point for launching an IPython kernel.
